# %% [markdown]
# ## <center>$\color{blue}{\text{Tecnológico de Monterrey}}$</center>  <center>$\color{blue}{\text{Campus Santa Fe}}$</center>
# ## <center>$\color{black}{\text{Mathematics and Data Science for Decision Making}}$</center>  <center>$\color{black}{\text{Name and Student ID: Miguel Angel Medina Ruperto a01023656}}$</center>
# ## <center>$\color{blue}{\text{Descriptive Statistics: Average Annual Wages}}$</center>

# %% [markdown]
# ![alt text](wages.jpg "Average Annual Wages")

# %% [markdown]
# ## $\color{blue}{\text{Introduction.}}$
# </br></br>
# <div style="text-align: justify"> Descriptive statistics provide simple summaries about the observations that have been made. Such summaries may be either quantitative or visual, i.e., summary statistics or simple-to-understand graphs. These summaries may either form the basis of the initial description of the data as part of a more extensive statistical analysis, or they may be sufficient in and of themselves for a particular investigation.Initially, when we get the data, instead of applying fancy algorithms and making some predictions, we first try to read and understand the data by applying statistical techniques.</div>
#
# </br></br>
#
# <div style="text-align: justify">We will root our discussion of statistics in real-world data taken from OECD.Stat homepage (https://stats.oecd.org/). In this notebook we describe an OECD (Organization for Economic Co-operation and Development) dataset containing data on average annual wages for full-time and full-year equivalent employees in the total economy. Average annual wages per full-time equivalent dependent employee are obtained by dividing the national-accounts-based total wage bill by the average number of employees in the total economy, which is then multiplied by the ratio of average usual weekly hours per full-time employee to average usually weekly hours for all employees. For more details, see:
#
# </br></br>
#
# - <http://www.oecd.org/els/oecd-employment-outlook-19991266.htm>
#
#
# - <http://www.oecd.org/employment/emp/onlineoecdemploymentdatabase.htm>
#
#
# - <http://www.oecd.org/els/emp/AVERAGE_WAGES.pdf> </div>

# %% [markdown]
# ## $\color{blue}{\text{Python Imports and Setup}}$
#
# </br></br>
#
# First we import the required libraries into the Jupyter Notebook.
#
#
# * In the cell below, we import the following packages (summarized here in no particular order):
#     * **NumPy** (<http://www.numpy.org/>)
#         * A fundamental package for generic N-dimensional array representation and manipulation.
#         * Also provides many methods that quickly and easily handle linear algebra, Fourier transforms, and random number generation capabilities.
#         * Part of the SciPy ecosystem of open-source mathematic and scientific Python packages.<br/><br/>
#     * **pandas** (<https://pandas.pydata.org/>)
#         * Links up nicely with NumPy by defining, and being based entirely around, two powerful data structures: the Series, and the DataFrame. The former is like a column of data $\dots$ while the latter is like a table of data.
#         * Therein provides very, very!! useful tools for loading, working, and manipulating data.
#         * Also part of the SciPy ecosystem of packages.<br/><br/>
#     * **SciPy** (<https://scipy.org/> and in particular <https://docs.scipy.org/doc/scipy/reference/stats.html>)
#         * We load the `stats` library of the SciPy package in order to access the significant range of statistical functions, tests, and transformations $\dots$ as well as probability distributions $\dots$ that it provides.<br/><br/>
#     * **matplotlib** (<https://matplotlib.org/>)
#         * The official Python 2D and 3D plotting library for generating plots, histograms, power spectra, bar charts, errorcharts, scatterplots, etc., etc.
#         * Also part of the SciPy ecosystem of packages.<br/><br/>
#     * **seaborn** (<http://seaborn.pydata.org/>)
#         * Built on top of matplotlib (and seamlessly falling back to matplotlib API when in doubt) - seaborn is a more modern data visualization library than matplotlib.
#         * In particular it provides a high level interface (again, on top of matplotlib) for drawing attractive and informative statistical graphics.
#
#
# * Note: later on we will be importing more Python packages and tools.

# %%
# This command (%matplotlib inline) simply ensures that any plot we produce in this notebook is immediately displayed on screen, 
# directly below the code that created it.
# %matplotlib inline

try:
    import scipy.stats as stats
    import numpy as np
    import pandas as pd
    import matplotlib.pyplot as plt
    import seaborn as sns
except ModuleNotFoundError as err:
    print("Python says:", err, "... possibly because it isn't installed on your system?")
except:
    print("Some other error occurred when importing.")
else:
    print("Imports successful!")
    sns.set()
# Out:
# Imports successful!

# %% [markdown]
# ## $\color{blue}{\text{Download, Open and Read the Data}}$
# * Head to the OECD.Stat homepage, at <https://stats.oecd.org>, and under Labour>Earnings, download the dataset we'll be using for this activity. It is the Average annual wages CSV file, rename it as `wage` and save it in the same folder of this notebook.
#
#
# * Read the file in using panda's `read_csv` method (<https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html>). Name the file `wage`.

# %%
# Read the data in, from a CSV file, and store the data in a DataFrame.
# The DataFrame created will take on the column names as they are provided in the file.
wage = pd.read_csv('wage.csv')

# %% [markdown]
# * Double-check the type of the object `wage` $\dots$ **_Hint_**: it should be a pandas DataFrame!
# * And if you wish, head to <https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html> to learn more about the DataFrame structure.

# %%
type(wage)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# * Check the shape of the DataFrame; how many rows and columns are there?

# %%
# The shape of the DataFrame
wage.shape
# Out:
# (2520, 15)

# %% [markdown]
# ## $\color{blue}{\text{Data Exploration}}$
#
#
# * Since the file is small enough (338 KB), we can print its contents.
#
# * $\color{red}{\text{Note:}}$
#     * Large files will either crash the Notebook, or take too long to process, or take up a rididculous amount of space in your Notebook (which you don't want to have to take forever to scroll through); besides, getting a grasp of what your data looks like is part of the challenge of data exploration!
#
#     * We are lucky that the dataset is already structured into rows and columns $\dots$ much like a Microsoft Excel spreadsheet.
#
# * However, it is still **invaluable to thoroughly explore the dataset** to be totally satisfied that what OECD (or wherever else you happen to get data from) claims about the dataset is actually true. For example, how can we be completely confident there are no null values `n/a` or `nan` to deal with?

# %%
# Print contents                                                
wage
# Out:
#      COUNTRY    Country  SERIES  \
# 0        AUS  Australia   CPNCU
# 1        AUS  Australia   CPNCU
# 2        AUS  Australia   CPNCU
# 3        AUS  Australia   CPNCU
# 4        AUS  Australia   CPNCU
# 5        AUS  Australia   CPNCU
# 6        AUS  Australia   CPNCU
# 7        AUS  Australia   CPNCU
# 8        AUS  Australia   CPNCU
# 9        AUS  Australia   CPNCU
# 10       AUS  Australia   CPNCU
# 11       AUS  Australia   CPNCU
# 12       AUS  Australia   CPNCU
# 13       AUS  Australia   CPNCU
# 14       AUS  Australia   CPNCU
# 15       AUS  Australia   CPNCU
# 16       AUS  Australia   CPNCU
# 17       AUS  Australia   CPNCU
# 18       AUT    Austria   CPNCU
# 19       AUT    Austria   CPNCU
# 20       AUT    Austria   CPNCU
# 21       AUT    Austria   CPNCU
# 22       AUT    Austria   CPNCU
# 23       AUT    Austria   CPNCU
# 24       AUT    Austria   CPNCU
# 25       AUT    Austria   CPNCU
# 26       AUT    Austria   CPNCU
# 27       AUT    Austria   CPNCU
# 28       AUT    Austria   CPNCU
# 2494           In 2017 constant prices at 2017 USD PPPs  2010  2010       USD
# 2495           In 2017 constant prices at 2017 USD PPPs  2011  2011       USD
# 2496           In 2017 constant prices at 2017 USD PPPs  2012  2012       USD
# 2497           In 2017 constant prices at 2017 USD PPPs  2013  2013       USD
# 2498           In 2017 constant prices at 2017 USD PPPs  2014  2014       USD
# 2499           In 2017 constant prices at 2017 USD PPPs  2015  2015       USD
# 2500           In 2017 constant prices at 2017 USD PPPs  2016  2016       USD
# 2501           In 2017 constant prices at 2017 USD PPPs  2017  2017       USD
# 2502  In 2017 constant prices at 2017 USD exchange r...  2000  2000       USD
# 2503  In 2017 constant prices at 2017 USD exchange r...  2001  2001       USD
# 2504  In 2017 constant prices at 2017 USD exchange r...  2002  2002       USD
# 2505  In 2017 constant prices at 2017 USD exchange r...  2003  2003       USD
# 2506  In 2017 constant prices at 2017 USD exchange r...  2004  2004       USD
# 2507  In 2017 constant prices at 2017 USD exchange r...  2005  2005       USD
# 2508  In 2017 constant prices at 2017 USD exchange r...  2006  2006       USD
# 2509  In 2017 constant prices at 2017 USD exchange r...  2007  2007       USD
# 2510  In 2017 constant prices at 2017 USD exchange r...  2008  2008       USD
# 2511  In 2017 constant prices at 2017 USD exchange r...  2009  2009       USD
# 2512  In 2017 constant prices at 2017 USD exchange r...  2010  2010       USD
# 2513  In 2017 constant prices at 2017 USD exchange r...  2011  2011       USD
# 2514  In 2017 constant prices at 2017 USD exchange r...  2012  2012       USD
# 2515  In 2017 constant prices at 2017 USD exchange r...  2013  2013       USD
# 2516  In 2017 constant prices at 2017 USD exchange r...  2014  2014       USD
# 2517  In 2017 constant prices at 2017 USD exchange r...  2015  2015       USD
# 2518  In 2017 constant prices at 2017 USD exchange r...  2016  2016       USD
# 2519  In 2017 constant prices at 2017 USD exchange r...  2017  2017       USD
#
#                    Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0     Australian Dollar               0     Units                    NaN
# 1     Australian Dollar               0     Units                    NaN
# 2     Australian Dollar               0     Units                    NaN
# 3     Australian Dollar               0     Units                    NaN
# 4     Australian Dollar               0     Units                    NaN
# 5     Australian Dollar               0     Units                    NaN
# 6     Australian Dollar               0     Units                    NaN
# 7     Australian Dollar               0     Units                    NaN
# 8     Australian Dollar               0     Units                    NaN
# 9     Australian Dollar               0     Units                    NaN
# 10    Australian Dollar               0     Units                    NaN
# 11    Australian Dollar               0     Units                    NaN
# 12    Australian Dollar               0     Units                    NaN
# 13    Australian Dollar               0     Units                    NaN
# 14    Australian Dollar               0     Units                    NaN
# 15    Australian Dollar               0     Units                    NaN
# 16    Australian Dollar               0     Units                    NaN
# 17    Australian Dollar               0     Units                    NaN
# 18                 Euro               0     Units                    NaN
# 19                 Euro               0     Units                    NaN
# 20                 Euro               0     Units                    NaN
# 21                 Euro               0     Units                    NaN
# 22                 Euro               0     Units                    NaN
# 23                 Euro               0     Units                    NaN
# 24                 Euro               0     Units                    NaN
# 25                 Euro               0     Units                    NaN
# 26                 Euro               0     Units                    NaN
# 27                 Euro               0     Units                    NaN
# 28                 Euro               0     Units                    NaN
# 29                 Euro               0     Units                    NaN
# ...                 ...             ...       ...                    ...
# 2490          US Dollar               0     Units                 2016.0
# 2491          US Dollar               0     Units                 2016.0
# 2492          US Dollar               0     Units                 2016.0
# 2493          US Dollar               0     Units                 2016.0
# 2494          US Dollar               0     Units                 2016.0
# 2495          US Dollar               0     Units                 2016.0
# 2496          US Dollar               0     Units                 2016.0
# 2497          US Dollar               0     Units                 2016.0
# 2498          US Dollar               0     Units                 2016.0
# 2499          US Dollar               0     Units                 2016.0
# 2500          US Dollar               0     Units                 2016.0
# 2501          US Dollar               0     Units                 2016.0
# 2502          US Dollar               0     Units                 2016.0
# 2503          US Dollar               0     Units                 2016.0
# 2504          US Dollar               0     Units                 2016.0
# 2505          US Dollar               0     Units                 2016.0
# 2506          US Dollar               0     Units                 2016.0
# 2507          US Dollar               0     Units                 2016.0
# 2508          US Dollar               0     Units                 2016.0
# 2509          US Dollar               0     Units                 2016.0
# 2510          US Dollar               0     Units                 2016.0
# 2511          US Dollar               0     Units                 2016.0
# 2512          US Dollar               0     Units                 2016.0
# 2513          US Dollar               0     Units                 2016.0
# 2514          US Dollar               0     Units                 2016.0
# 2515          US Dollar               0     Units                 2016.0
# 2516          US Dollar               0     Units                 2016.0
# 2517          US Dollar               0     Units                 2016.0
# 2518          US Dollar               0     Units                 2016.0
# 2519          US Dollar               0     Units                 2016.0
#
#       Reference Period         Value  Flag Codes  Flags
# 0                  NaN  47222.715450         NaN    NaN
# 1                  NaN  48366.628497         NaN    NaN
# 2                  NaN  50109.137562         NaN    NaN
# 3                  NaN  51867.999938         NaN    NaN
# 4                  NaN  54283.669777         NaN    NaN
# 5                  NaN  56174.404861         NaN    NaN
# 6                  NaN  58577.029175         NaN    NaN
# 7                  NaN  62067.955573         NaN    NaN
# 8                  NaN  64554.535193         NaN    NaN
# 9                  NaN  65621.764713         NaN    NaN
# 10                 NaN  69386.496731         NaN    NaN
# 11                 NaN  73284.712625         NaN    NaN
# 12                 NaN  75467.729160         NaN    NaN
# 13                 NaN  76898.549598         NaN    NaN
# 14                 NaN  78929.862458         NaN    NaN
# 15                 NaN  79439.700219         NaN    NaN
# 16                 NaN  80203.850722         NaN    NaN
# 17                 NaN  80407.448452         NaN    NaN
# 18                 NaN  27950.103312         NaN    NaN
# 19                 NaN  28525.480599         NaN    NaN
# 20                 NaN  29266.445737         NaN    NaN
# 21                 NaN  29792.470499         NaN    NaN
# 22                 NaN  30888.209994         NaN    NaN
# 23                 NaN  31795.430063         NaN    NaN
# 24                 NaN  32930.827747         NaN    NaN
# 25                 NaN  33918.386510         NaN    NaN
# 26                 NaN  35239.176867         NaN    NaN
# 27                 NaN  35974.813515         NaN    NaN
# 28                 NaN  36436.831209         NaN    NaN
# 29                 NaN  37176.416607         NaN    NaN
# ...                ...           ...         ...    ...
# 2490            2016.0  15788.041043         NaN    NaN
# 2491            2016.0  17403.476599         NaN    NaN
# 2492            2016.0  19086.880917         NaN    NaN
# 2493            2016.0  17519.005620         NaN    NaN
# 2494            2016.0  17530.170933         NaN    NaN
# 2495            2016.0  18345.121936         NaN    NaN
# 2496            2016.0  18854.027163         NaN    NaN
# 2497            2016.0  19607.955536         NaN    NaN
# 2498            2016.0  20392.893273         NaN    NaN
# 2499            2016.0  21416.724468         NaN    NaN
# 2500            2016.0  22562.385292         NaN    NaN
# 2501            2016.0  24286.869243         NaN    NaN
# 2502            2016.0   5576.006699         NaN    NaN
# 2503            2016.0   5895.331499         NaN    NaN
# 2504            2016.0   6153.414757         NaN    NaN
# 2505            2016.0   6562.257351         NaN    NaN
# 2506            2016.0   7102.612860         NaN    NaN
# 2507            2016.0   7869.101211         NaN    NaN
# 2508            2016.0   9223.898465         NaN    NaN
# 2509            2016.0  10167.689623         NaN    NaN
# 2510            2016.0  11151.190392         NaN    NaN
# 2511            2016.0  10235.185518         NaN    NaN
# 2512            2016.0  10241.708665         NaN    NaN
# 2513            2016.0  10717.830135         NaN    NaN
# 2514            2016.0  11015.149487         NaN    NaN
# 2515            2016.0  11455.619508         NaN    NaN
# 2516            2016.0  11914.206230         NaN    NaN
# 2517            2016.0  12512.362452         NaN    NaN
# 2518            2016.0  13181.695594         NaN    NaN
# 2519            2016.0  14189.196450         NaN    NaN
#
# [2520 rows x 15 columns]

# %%
# To get a grasp of your data, print the first 5 rows (5 is the default)
wage.head()
# Out:
#   COUNTRY    Country SERIES                 Series  TIME  Time Unit Code  \
# 0     AUS  Australia  CPNCU  Current prices in NCU  2000  2000       AUD
# 1     AUS  Australia  CPNCU  Current prices in NCU  2001  2001       AUD
# 2     AUS  Australia  CPNCU  Current prices in NCU  2002  2002       AUD
# 3     AUS  Australia  CPNCU  Current prices in NCU  2003  2003       AUD
# 4     AUS  Australia  CPNCU  Current prices in NCU  2004  2004       AUD
#
#                 Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0  Australian Dollar               0     Units                    NaN
# 1  Australian Dollar               0     Units                    NaN
# 2  Australian Dollar               0     Units                    NaN
# 3  Australian Dollar               0     Units                    NaN
# 4  Australian Dollar               0     Units                    NaN
#
#    Reference Period         Value  Flag Codes  Flags
# 0               NaN  47222.715450         NaN    NaN
# 1               NaN  48366.628497         NaN    NaN
# 2               NaN  50109.137562         NaN    NaN
# 3               NaN  51867.999938         NaN    NaN
# 4               NaN  54283.669777         NaN    NaN

# %%
# Now print the last 5 rows
wage.tail()
# Out:
#      COUNTRY    Country SERIES  \
# 2515     LTU  Lithuania  USDEX
# 2516     LTU  Lithuania  USDEX
# 2517     LTU  Lithuania  USDEX
# 2518     LTU  Lithuania  USDEX
# 2519     LTU  Lithuania  USDEX
#
#                                                  Series  TIME  Time Unit Code  \
# 2515  In 2017 constant prices at 2017 USD exchange r...  2013  2013       USD
# 2516  In 2017 constant prices at 2017 USD exchange r...  2014  2014       USD
# 2517  In 2017 constant prices at 2017 USD exchange r...  2015  2015       USD
# 2518  In 2017 constant prices at 2017 USD exchange r...  2016  2016       USD
# 2519  In 2017 constant prices at 2017 USD exchange r...  2017  2017       USD
#
#            Unit  PowerCode Code PowerCode  Reference Period Code  \
# 2515  US Dollar               0     Units                 2016.0
# 2516  US Dollar               0     Units                 2016.0
# 2517  US Dollar               0     Units                 2016.0
# 2518  US Dollar               0     Units                 2016.0
# 2519  US Dollar               0     Units                 2016.0
#
#       Reference Period         Value  Flag Codes  Flags
# 2515            2016.0  11455.619508         NaN    NaN
# 2516            2016.0  11914.206230         NaN    NaN
# 2517            2016.0  12512.362452         NaN    NaN
# 2518            2016.0  13181.695594         NaN    NaN
# 2519            2016.0  14189.196450         NaN    NaN

# %%
# Or print the first 10 rows
wage.head(10)
# Out:
#   COUNTRY    Country SERIES                 Series  TIME  Time Unit Code  \
# 0     AUS  Australia  CPNCU  Current prices in NCU  2000  2000       AUD
# 1     AUS  Australia  CPNCU  Current prices in NCU  2001  2001       AUD
# 2     AUS  Australia  CPNCU  Current prices in NCU  2002  2002       AUD
# 3     AUS  Australia  CPNCU  Current prices in NCU  2003  2003       AUD
# 4     AUS  Australia  CPNCU  Current prices in NCU  2004  2004       AUD
# 5     AUS  Australia  CPNCU  Current prices in NCU  2005  2005       AUD
# 6     AUS  Australia  CPNCU  Current prices in NCU  2006  2006       AUD
# 7     AUS  Australia  CPNCU  Current prices in NCU  2007  2007       AUD
# 8     AUS  Australia  CPNCU  Current prices in NCU  2008  2008       AUD
# 9     AUS  Australia  CPNCU  Current prices in NCU  2009  2009       AUD
#
#                 Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0  Australian Dollar               0     Units                    NaN
# 1  Australian Dollar               0     Units                    NaN
# 2  Australian Dollar               0     Units                    NaN
# 3  Australian Dollar               0     Units                    NaN
# 4  Australian Dollar               0     Units                    NaN
# 5  Australian Dollar               0     Units                    NaN
# 6  Australian Dollar               0     Units                    NaN
# 7  Australian Dollar               0     Units                    NaN
# 8  Australian Dollar               0     Units                    NaN
# 9  Australian Dollar               0     Units                    NaN
#
#    Reference Period         Value  Flag Codes  Flags
# 0               NaN  47222.715450         NaN    NaN
# 1               NaN  48366.628497         NaN    NaN
# 2               NaN  50109.137562         NaN    NaN
# 3               NaN  51867.999938         NaN    NaN
# 4               NaN  54283.669777         NaN    NaN
# 5               NaN  56174.404861         NaN    NaN
# 6               NaN  58577.029175         NaN    NaN
# 7               NaN  62067.955573         NaN    NaN
# 8               NaN  64554.535193         NaN    NaN
# 9               NaN  65621.764713         NaN    NaN

# %%
# Or the last 20 rows
wage.tail(20)
# Out:
#      COUNTRY    Country  SERIES  \
# 2500     LTU  Lithuania  USDPPP
# 2501     LTU  Lithuania  USDPPP
# 2502     LTU  Lithuania   USDEX
# 2503     LTU  Lithuania   USDEX
# 2504     LTU  Lithuania   USDEX
# 2505     LTU  Lithuania   USDEX
# 2506     LTU  Lithuania   USDEX
# 2507     LTU  Lithuania   USDEX
# 2508     LTU  Lithuania   USDEX
# 2509     LTU  Lithuania   USDEX
# 2510     LTU  Lithuania   USDEX
# 2511     LTU  Lithuania   USDEX
# 2512     LTU  Lithuania   USDEX
# 2513     LTU  Lithuania   USDEX
# 2514     LTU  Lithuania   USDEX
# 2509            2016.0  10167.689623         NaN    NaN
# 2510            2016.0  11151.190392         NaN    NaN
# 2511            2016.0  10235.185518         NaN    NaN
# 2512            2016.0  10241.708665         NaN    NaN
# 2513            2016.0  10717.830135         NaN    NaN
# 2514            2016.0  11015.149487         NaN    NaN
# 2515            2016.0  11455.619508         NaN    NaN
# 2516            2016.0  11914.206230         NaN    NaN
# 2517            2016.0  12512.362452         NaN    NaN
# 2518            2016.0  13181.695594         NaN    NaN
# 2519            2016.0  14189.196450         NaN    NaN

# %%
wage[10:20]
# Out:
#    COUNTRY    Country SERIES                 Series  TIME  Time Unit Code  \
# 10     AUS  Australia  CPNCU  Current prices in NCU  2010  2010       AUD
# 11     AUS  Australia  CPNCU  Current prices in NCU  2011  2011       AUD
# 12     AUS  Australia  CPNCU  Current prices in NCU  2012  2012       AUD
# 13     AUS  Australia  CPNCU  Current prices in NCU  2013  2013       AUD
# 14     AUS  Australia  CPNCU  Current prices in NCU  2014  2014       AUD
# 15     AUS  Australia  CPNCU  Current prices in NCU  2015  2015       AUD
# 16     AUS  Australia  CPNCU  Current prices in NCU  2016  2016       AUD
# 17     AUS  Australia  CPNCU  Current prices in NCU  2017  2017       AUD
# 18     AUT    Austria  CPNCU  Current prices in NCU  2000  2000       EUR
# 19     AUT    Austria  CPNCU  Current prices in NCU  2001  2001       EUR
#
#                  Unit  PowerCode Code PowerCode  Reference Period Code  \
# 10  Australian Dollar               0     Units                    NaN
# 11  Australian Dollar               0     Units                    NaN
# 12  Australian Dollar               0     Units                    NaN
# 13  Australian Dollar               0     Units                    NaN
# 14  Australian Dollar               0     Units                    NaN
# 15  Australian Dollar               0     Units                    NaN
# 16  Australian Dollar               0     Units                    NaN
# 17  Australian Dollar               0     Units                    NaN
# 18               Euro               0     Units                    NaN
# 19               Euro               0     Units                    NaN
#
#     Reference Period         Value  Flag Codes  Flags
# 10               NaN  69386.496731         NaN    NaN
# 11               NaN  73284.712625         NaN    NaN
# 12               NaN  75467.729160         NaN    NaN
# 13               NaN  76898.549598         NaN    NaN
# 14               NaN  78929.862458         NaN    NaN
# 15               NaN  79439.700219         NaN    NaN
# 16               NaN  80203.850722         NaN    NaN
# 17               NaN  80407.448452         NaN    NaN
# 18               NaN  27950.103312         NaN    NaN
# 19               NaN  28525.480599         NaN    NaN

# %% [markdown]
# * As you can see, there are null values `nan` in the dataset.
#
#
# * Check for null values in the data set, per column and on a specific column.
#
#
# * Fill null values with an empty space `" "` and store your new DataFrame with the same name: `wage`.

# %%
# Null values in the DataFrame
wage.isnull()
# Out:
#       COUNTRY  Country  SERIES  Series   TIME   Time  Unit Code   Unit  \
# 0       False    False   False   False  False  False      False  False
# 1       False    False   False   False  False  False      False  False
# 2       False    False   False   False  False  False      False  False
# 3       False    False   False   False  False  False      False  False
# 4       False    False   False   False  False  False      False  False
# 5       False    False   False   False  False  False      False  False
# 6       False    False   False   False  False  False      False  False
# 7       False    False   False   False  False  False      False  False
# 8       False    False   False   False  False  False      False  False
# 9       False    False   False   False  False  False      False  False
# 10      False    False   False   False  False  False      False  False
# 11      False    False   False   False  False  False      False  False
# 12      False    False   False   False  False  False      False  False
# 13      False    False   False   False  False  False      False  False
# 14      False    False   False   False  False  False      False  False
# 15      False    False   False   False  False  False      False  False
# 16      False    False   False   False  False  False      False  False
# 17      False    False   False   False  False  False      False  False
# 18      False    False   False   False  False  False      False  False
# 19      False    False   False   False  False  False      False  False
# 20      False    False   False   False  False  False      False  False
# 21      False    False   False   False  False  False      False  False
# 22      False    False   False   False  False  False      False  False
# 23      False    False   False   False  False  False      False  False
# 24      False    False   False   False  False  False      False  False
# 25      False    False   False   False  False  False      False  False
# 26      False    False   False   False  False  False      False  False
# 27      False    False   False   False  False  False      False  False
# 28      False    False   False   False  False  False      False  False
# 29      False    False   False   False  False  False      False  False
# ...       ...      ...     ...     ...    ...    ...        ...    ...
# 2490    False    False   False   False  False  False      False  False
# 2491    False    False   False   False  False  False      False  False
# 2492    False    False   False   False  False  False      False  False
# 2493    False    False   False   False  False  False      False  False
# 2494    False    False   False   False  False  False      False  False
# 2495    False    False   False   False  False  False      False  False
# 2496    False    False   False   False  False  False      False  False
# 2497    False    False   False   False  False  False      False  False
# 2498    False    False   False   False  False  False      False  False
# 2499    False    False   False   False  False  False      False  False
# 2500    False    False   False   False  False  False      False  False
# 2501    False    False   False   False  False  False      False  False
# 2502    False    False   False   False  False  False      False  False
# 2503    False    False   False   False  False  False      False  False
# 2504    False    False   False   False  False  False      False  False
# 2505    False    False   False   False  False  False      False  False
# 2506    False    False   False   False  False  False      False  False
# 2507    False    False   False   False  False  False      False  False
# 2508    False    False   False   False  False  False      False  False
# 2509    False    False   False   False  False  False      False  False
# 2510    False    False   False   False  False  False      False  False
# 2511    False    False   False   False  False  False      False  False
# 2512    False    False   False   False  False  False      False  False
# 2513    False    False   False   False  False  False      False  False
# 2514    False    False   False   False  False  False      False  False
# 2515    False    False   False   False  False  False      False  False
# 2516    False    False   False   False  False  False      False  False
# 2517    False    False   False   False  False  False      False  False
# 2518    False    False   False   False  False  False      False  False
# 2519    False    False   False   False  False  False      False  False
#
#       PowerCode Code  PowerCode  Reference Period Code  Reference Period  \
# 0              False      False                   True              True
# 1              False      False                   True              True
# 2              False      False                   True              True
# 3              False      False                   True              True
# 4              False      False                   True              True
# 5              False      False                   True              True
# 6              False      False                   True              True
# 7              False      False                   True              True
# 8              False      False                   True              True
# 9              False      False                   True              True
# 10             False      False                   True              True
# 11             False      False                   True              True
# 12             False      False                   True              True
# 13             False      False                   True              True
# 14             False      False                   True              True
# 15             False      False                   True              True
# 16             False      False                   True              True
# 17             False      False                   True              True
# 18             False      False                   True              True
# 19             False      False                   True              True
# 20             False      False                   True              True
# 21             False      False                   True              True
# 22             False      False                   True              True
# 23             False      False                   True              True
# 24             False      False                   True              True
# 25             False      False                   True              True
# 26             False      False                   True              True
# 27             False      False                   True              True
# 28             False      False                   True              True
# 29             False      False                   True              True
# ...              ...        ...                    ...               ...
# 2490           False      False                  False             False
# 2491           False      False                  False             False
# 2492           False      False                  False             False
# 2493           False      False                  False             False
# 2494           False      False                  False             False
# 2495           False      False                  False             False
# 2496           False      False                  False             False
# 2497           False      False                  False             False
# 2498           False      False                  False             False
# 2499           False      False                  False             False
# 2500           False      False                  False             False
# 2501           False      False                  False             False
# 2502           False      False                  False             False
# 2503           False      False                  False             False
# 2504           False      False                  False             False
# 2505           False      False                  False             False
# 2506           False      False                  False             False
# 2507           False      False                  False             False
# 2508           False      False                  False             False
# 2509           False      False                  False             False
# 2510           False      False                  False             False
# 2511           False      False                  False             False
# 2512           False      False                  False             False
# 2513           False      False                  False             False
# 2514           False      False                  False             False
# 2515           False      False                  False             False
# 2516           False      False                  False             False
# 2517           False      False                  False             False
# 2518           False      False                  False             False
# 2519           False      False                  False             False
#
#       Value  Flag Codes  Flags
# 0     False        True   True
# 1     False        True   True
# 2     False        True   True
# 3     False        True   True
# 4     False        True   True
# 5     False        True   True
# 6     False        True   True
# 7     False        True   True
# 8     False        True   True
# 9     False        True   True
# 10    False        True   True
# 11    False        True   True
# 12    False        True   True
# 13    False        True   True
# 14    False        True   True
# 15    False        True   True
# 16    False        True   True
# 17    False        True   True
# 18    False        True   True
# 19    False        True   True
# 20    False        True   True
# 21    False        True   True
# 22    False        True   True
# 23    False        True   True
# 24    False        True   True
# 25    False        True   True
# 26    False        True   True
# 27    False        True   True
# 28    False        True   True
# 29    False        True   True
# ...     ...         ...    ...
# 2490  False        True   True
# 2491  False        True   True
# 2492  False        True   True
# 2493  False        True   True
# 2494  False        True   True
# 2495  False        True   True
# 2496  False        True   True
# 2497  False        True   True
# 2498  False        True   True
# 2499  False        True   True
# 2500  False        True   True
# 2501  False        True   True
# 2502  False        True   True
# 2503  False        True   True
# 2504  False        True   True
# 2505  False        True   True
# 2506  False        True   True
# 2507  False        True   True
# 2508  False        True   True
# 2509  False        True   True
# 2510  False        True   True
# 2511  False        True   True
# 2512  False        True   True
# 2513  False        True   True
# 2514  False        True   True
# 2515  False        True   True
# 2516  False        True   True
# 2517  False        True   True
# 2518  False        True   True
# 2519  False        True   True
#
# [2520 rows x 15 columns]

# %%
# Null values per column
wage.isnull().sum()
# Out:
# COUNTRY                     0
# Country                     0
# SERIES                      0
# Series                      0
# TIME                        0
# Time                        0
# Unit Code                   0
# Unit                        0
# PowerCode Code              0
# PowerCode                   0
# Reference Period Code     630
# Reference Period          630
# Value                       0
# Flag Codes               2520
# Flags                    2520
# dtype: int64

# %%
# Or null values in a specific column
wage['Reference Period'].isnull().sum()
# Out:
# 630

# %%
# Fill null values with an empty space and store the new DataFrame under the same name: "wage"
wagena = wage.fillna(" ")

# %% [markdown]
# ## $\color{blue}{\text{Task: Check for null values in the new DataFrame, you shoud have none!}}$

# %%
# Type your code:
wagena.isnull().sum()
# Out:
# COUNTRY                  0
# Country                  0
# SERIES                   0
# Series                   0
# TIME                     0
# Time                     0
# Unit Code                0
# Unit                     0
# PowerCode Code           0
# PowerCode                0
# Reference Period Code    0
# Reference Period         0
# Value                    0
# Flag Codes               0
# Flags                    0
# dtype: int64

# %% [markdown]
# * Properly rename your columns if needed

# %%
# Rename Columns
wagena.rename(columns={'COUNTRY': 'Country Code', 'SERIES': 'Series Code', 'Time': 'Year', 'Value': 'Average Annual Wages'}, inplace=True)

# %% [markdown]
# ## $\color{blue}{\text{Task: Print your new DataFrame}}$
#
# * Hint: The name didn't change

# %%
# Print the contents of the new object:
wagena
# Out:
#      Country Code    Country Series Code  \
# 0             AUS  Australia       CPNCU
# 1             AUS  Australia       CPNCU
# 2             AUS  Australia       CPNCU
# 3             AUS  Australia       CPNCU
# 4             AUS  Australia       CPNCU
# 5             AUS  Australia       CPNCU
# 6             AUS  Australia       CPNCU
# 7             AUS  Australia       CPNCU
# 8             AUS  Australia       CPNCU
# 9             AUS  Australia       CPNCU
# 10            AUS  Australia       CPNCU
# 11            AUS  Australia       CPNCU
# 12            AUS  Australia       CPNCU
# 13            AUS  Australia       CPNCU
# 14            AUS  Australia       CPNCU
# 15            AUS  Australia       CPNCU
# 16            AUS  Australia       CPNCU
# 17            AUS  Australia       CPNCU
# 18            AUT    Austria       CPNCU
# 19            AUT    Austria       CPNCU
# 20            AUT    Austria       CPNCU
# 21            AUT    Austria       CPNCU
# 22            AUT    Austria       CPNCU
# 23            AUT    Austria       CPNCU
# 24            AUT    Austria       CPNCU
# 25            AUT    Austria       CPNCU
# 26            AUT    Austria       CPNCU
# 27            AUT    Austria       CPNCU
# 28            AUT    Austria       CPNCU
# 29            AUT    Austria       CPNCU
# ...           ...        ...         ...
# 2490          LTU  Lithuania      USDPPP
# 2491          LTU  Lithuania      USDPPP
# 2492          LTU  Lithuania      USDPPP
# 2493          LTU  Lithuania      USDPPP
# 2494          LTU  Lithuania      USDPPP
# 2495          LTU  Lithuania      USDPPP
# 2496          LTU  Lithuania      USDPPP
# 2497          LTU  Lithuania      USDPPP
# 2498          LTU  Lithuania      USDPPP
# 2499          LTU  Lithuania      USDPPP
# 2500          LTU  Lithuania      USDPPP
# 2501          LTU  Lithuania      USDPPP
# 2502          LTU  Lithuania       USDEX
# 2503          LTU  Lithuania       USDEX
# 2504          LTU  Lithuania       USDEX
# 2505          LTU  Lithuania       USDEX
# 2506          LTU  Lithuania       USDEX
# 2507          LTU  Lithuania       USDEX
# 2508          LTU  Lithuania       USDEX
# 2509          LTU  Lithuania       USDEX
# 2510          LTU  Lithuania       USDEX
# 2511          LTU  Lithuania       USDEX
# 2512          LTU  Lithuania       USDEX
# 2513          LTU  Lithuania       USDEX
# 2514          LTU  Lithuania       USDEX
# 2515          LTU  Lithuania       USDEX
# 2516          LTU  Lithuania       USDEX
# 2517          LTU  Lithuania       USDEX
# 2518          LTU  Lithuania       USDEX
# 2519          LTU  Lithuania       USDEX
#
#                                                  Series  TIME  Year Unit Code  \
# 0                                 Current prices in NCU  2000  2000       AUD
# 1                                 Current prices in NCU  2001  2001       AUD
# 2                                 Current prices in NCU  2002  2002       AUD
# 3                                 Current prices in NCU  2003  2003       AUD
# 4                                 Current prices in NCU  2004  2004       AUD
# 5                                 Current prices in NCU  2005  2005       AUD
# 6                                 Current prices in NCU  2006  2006       AUD
# 7                                 Current prices in NCU  2007  2007       AUD
# 29                             37176.416607
# ...               ...                   ...        ...   ...
# 2490             2016          15788.041043
# 2491             2016          17403.476599
# 2492             2016          19086.880917
# 2493             2016          17519.005620
# 2494             2016          17530.170933
# 2495             2016          18345.121936
# 2496             2016          18854.027163
# 2497             2016          19607.955536
# 2498             2016          20392.893273
# 2499             2016          21416.724468
# 2500             2016          22562.385292
# 2501             2016          24286.869243
# 2502             2016           5576.006699
# 2503             2016           5895.331499
# 2504             2016           6153.414757
# 2505             2016           6562.257351
# 2506             2016           7102.612860
# 2507             2016           7869.101211
# 2508             2016           9223.898465
# 2509             2016          10167.689623
# 2510             2016          11151.190392
# 2511             2016          10235.185518
# 2512             2016          10241.708665
# 2513             2016          10717.830135
# 2514             2016          11015.149487
# 2515             2016          11455.619508
# 2516             2016          11914.206230
# 2517             2016          12512.362452
# 2518             2016          13181.695594
# 2519             2016          14189.196450
#
# [2520 rows x 15 columns]

# %% [markdown]
# * It seems that the columns `TIME` and `Year` have the same values. Let's check if this is true

# %%
wagena['TIME'].equals(wagena['Year'])
# Out:
# True

# %% [markdown]
# * Since we have repeated columns and empty columns, let's drop these out

# %%
wageoff = wagena.drop(['TIME', 'Flag Codes', 'Flags'], axis=1)
wageoff
# Out:
#      Country Code    Country Series Code  \
# 0             AUS  Australia       CPNCU
# 1             AUS  Australia       CPNCU
# 2             AUS  Australia       CPNCU
# 3             AUS  Australia       CPNCU
# 4             AUS  Australia       CPNCU
# 5             AUS  Australia       CPNCU
# 6             AUS  Australia       CPNCU
# 7             AUS  Australia       CPNCU
# 8             AUS  Australia       CPNCU
# 9             AUS  Australia       CPNCU
# 10            AUS  Australia       CPNCU
# 11            AUS  Australia       CPNCU
# 12            AUS  Australia       CPNCU
# 13            AUS  Australia       CPNCU
# 14            AUS  Australia       CPNCU
# 15            AUS  Australia       CPNCU
# 16            AUS  Australia       CPNCU
# 17            AUS  Australia       CPNCU
# 18            AUT    Austria       CPNCU
# 19            AUT    Austria       CPNCU
# 20            AUT    Austria       CPNCU
# 21            AUT    Austria       CPNCU
# 22            AUT    Austria       CPNCU
# 23            AUT    Austria       CPNCU
# 24            AUT    Austria       CPNCU
# 25            AUT    Austria       CPNCU
# 26            AUT    Austria       CPNCU
# 27            AUT    Austria       CPNCU
# 28            AUT    Austria       CPNCU
# 29            AUT    Austria       CPNCU
# ...           ...        ...         ...
# 2490          LTU  Lithuania      USDPPP
# 2491          LTU  Lithuania      USDPPP
# 2492          LTU  Lithuania      USDPPP
# 2493          LTU  Lithuania      USDPPP
# 2494          LTU  Lithuania      USDPPP
# 2495          LTU  Lithuania      USDPPP
# 2496          LTU  Lithuania      USDPPP
# 2497          LTU  Lithuania      USDPPP
# 2498          LTU  Lithuania      USDPPP
# 2499          LTU  Lithuania      USDPPP
# 2500          LTU  Lithuania      USDPPP
# 2501          LTU  Lithuania      USDPPP
# 2502          LTU  Lithuania       USDEX
# 2503          LTU  Lithuania       USDEX
# 2504          LTU  Lithuania       USDEX
# 2505          LTU  Lithuania       USDEX
# 2506          LTU  Lithuania       USDEX
# 2507          LTU  Lithuania       USDEX
# 2508          LTU  Lithuania       USDEX
# 2509          LTU  Lithuania       USDEX
# 2510          LTU  Lithuania       USDEX
# 2511          LTU  Lithuania       USDEX
# 2512          LTU  Lithuania       USDEX
# 2513          LTU  Lithuania       USDEX
# 2514          LTU  Lithuania       USDEX
# 2515          LTU  Lithuania       USDEX
# 2516          LTU  Lithuania       USDEX
# 2517          LTU  Lithuania       USDEX
# 2518          LTU  Lithuania       USDEX
# 2519          LTU  Lithuania       USDEX
#
#                                                  Series  Year Unit Code  \
# 0                                 Current prices in NCU  2000       AUD
# 1                                 Current prices in NCU  2001       AUD
# 2                                 Current prices in NCU  2002       AUD
# 3                                 Current prices in NCU  2003       AUD
# 4                                 Current prices in NCU  2004       AUD
# 5                                 Current prices in NCU  2005       AUD
# 6                                 Current prices in NCU  2006       AUD
# 7                                 Current prices in NCU  2007       AUD
# 8                                 Current prices in NCU  2008       AUD
# 9                                 Current prices in NCU  2009       AUD
# 10                                Current prices in NCU  2010       AUD
# 11                                Current prices in NCU  2011       AUD
# 12                                Current prices in NCU  2012       AUD
# 13                                Current prices in NCU  2013       AUD
# 14                                Current prices in NCU  2014       AUD
# 15                                Current prices in NCU  2015       AUD
# 16                                Current prices in NCU  2016       AUD
# 17                                Current prices in NCU  2017       AUD
# 18                                Current prices in NCU  2000       EUR
# 19                                Current prices in NCU  2001       EUR
# 20                                Current prices in NCU  2002       EUR
# 21                                Current prices in NCU  2003       EUR
# 22                                Current prices in NCU  2004       EUR
# 23                                Current prices in NCU  2005       EUR
# 24                                Current prices in NCU  2006       EUR
# 25                                Current prices in NCU  2007       EUR
# 26                                Current prices in NCU  2008       EUR
# 27                                Current prices in NCU  2009       EUR
# 28                                Current prices in NCU  2010       EUR
# 29                                Current prices in NCU  2011       EUR
# ...                                                 ...   ...       ...
# 2490           In 2017 constant prices at 2017 USD PPPs  2006       USD
# 2491           In 2017 constant prices at 2017 USD PPPs  2007       USD
# 2492           In 2017 constant prices at 2017 USD PPPs  2008       USD
# 2493           In 2017 constant prices at 2017 USD PPPs  2009       USD
# 2494           In 2017 constant prices at 2017 USD PPPs  2010       USD
# 2495           In 2017 constant prices at 2017 USD PPPs  2011       USD
# 2496           In 2017 constant prices at 2017 USD PPPs  2012       USD
# 2497           In 2017 constant prices at 2017 USD PPPs  2013       USD
# 2498           In 2017 constant prices at 2017 USD PPPs  2014       USD
# 2499           In 2017 constant prices at 2017 USD PPPs  2015       USD
# 2500           In 2017 constant prices at 2017 USD PPPs  2016       USD
# 2501           In 2017 constant prices at 2017 USD PPPs  2017       USD
# 2502  In 2017 constant prices at 2017 USD exchange r...  2000       USD
# 2503  In 2017 constant prices at 2017 USD exchange r...  2001       USD
# 2504  In 2017 constant prices at 2017 USD exchange r...  2002       USD
# 2505  In 2017 constant prices at 2017 USD exchange r...  2003       USD
# 2506  In 2017 constant prices at 2017 USD exchange r...  2004       USD
# 2507  In 2017 constant prices at 2017 USD exchange r...  2005       USD
# 2508  In 2017 constant prices at 2017 USD exchange r...  2006       USD
# 4                              54283.669777
# 5                              56174.404861
# 6                              58577.029175
# 7                              62067.955573
# 8                              64554.535193
# 9                              65621.764713
# 10                             69386.496731
# 11                             73284.712625
# 12                             75467.729160
# 13                             76898.549598
# 14                             78929.862458
# 15                             79439.700219
# 16                             80203.850722
# 17                             80407.448452
# 18                             27950.103312
# 19                             28525.480599
# 20                             29266.445737
# 21                             29792.470499
# 22                             30888.209994
# 23                             31795.430063
# 24                             32930.827747
# 25                             33918.386510
# 26                             35239.176867
# 27                             35974.813515
# 28                             36436.831209
# 29                             37176.416607
# ...               ...                   ...
# 2490             2016          15788.041043
# 2491             2016          17403.476599
# 2492             2016          19086.880917
# 2493             2016          17519.005620
# 2494             2016          17530.170933
# 2495             2016          18345.121936
# 2496             2016          18854.027163
# 2497             2016          19607.955536
# 2498             2016          20392.893273
# 2499             2016          21416.724468
# 2500             2016          22562.385292
# 2501             2016          24286.869243
# 2502             2016           5576.006699
# 2503             2016           5895.331499
# 2504             2016           6153.414757
# 2505             2016           6562.257351
# 2506             2016           7102.612860
# 2507             2016           7869.101211
# 2508             2016           9223.898465
# 2509             2016          10167.689623
# 2510             2016          11151.190392
# 2511             2016          10235.185518
# 2512             2016          10241.708665
# 2513             2016          10717.830135
# 2514             2016          11015.149487
# 2515             2016          11455.619508
# 2516             2016          11914.206230
# 2517             2016          12512.362452
# 2518             2016          13181.695594
# 2519             2016          14189.196450
#
# [2520 rows x 12 columns]

# %% [markdown]
# * How many countries do we have in this dataset?

# %%
# Count the unique values in a cloumn
wageoff.Country.nunique()
# Out:
# 35

# %% [markdown]
# * What are these countries?

# %%
# List the names if the unique values in a column
wageoff.Country.unique()
# Out:
# array(['Australia', 'Austria', 'Belgium', 'Canada', 'Czech Republic',
#        'Denmark', 'Finland', 'France', 'Germany', 'Greece', 'Hungary',
#        'Ireland', 'Italy', 'Japan', 'Korea', 'Luxembourg', 'Netherlands',
#        'Norway', 'Poland', 'Portugal', 'Slovak Republic', 'Spain',
#        'Sweden', 'Switzerland', 'United Kingdom', 'United States',
#        'Israel', 'Slovenia', 'Estonia', 'Mexico', 'Iceland',
#        'New Zealand', 'Chile', 'Latvia', 'Lithuania'], dtype=object)

# %% [markdown]
# ## $\color{blue}{\text{Task: How many years are there in this dataset?}}$

# %%
# Type your code here:
wageoff.Year.nunique()
# Out:
# 18

# %% [markdown]
# ## $\color{blue}{\text{Task: List the unique Years}}$

# %%
# Type your code here:
wageoff.Year.unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %% [markdown]
# ## $\color{blue}{\text{Task: How many Series are there in this dataset?}}$

# %%
# Type your code here:
wageoff.Series.nunique()
# Out:
# 4

# %% [markdown]
# ## $\color{blue}{\text{Task: List the unique Series}}$

# %%
# Type your code here:
wageoff.Series.unique()
# Out:
# array(['Current prices in NCU', '2017 constant prices and NCU',
#        'In 2017 constant prices at 2017 USD PPPs',
#        'In 2017 constant prices at 2017 USD exchange rates'], dtype=object)

# %% [markdown]
# * We can also extract specific columns, say: `Country`, `Series`, `Year`, `Unit` and `Average Annual Wages`
# 2002  Australian Dollar          50109.137562
# 2003  Australian Dollar          51867.999938
# 2004  Australian Dollar          54283.669777
# 2005  Australian Dollar          56174.404861
# 2006  Australian Dollar          58577.029175
# 2007  Australian Dollar          62067.955573
# 2008  Australian Dollar          64554.535193
# 2009  Australian Dollar          65621.764713
# 2010  Australian Dollar          69386.496731
# 2011  Australian Dollar          73284.712625
# 2012  Australian Dollar          75467.729160
# 2013  Australian Dollar          76898.549598
# 2014  Australian Dollar          78929.862458
# 2015  Australian Dollar          79439.700219
# 2016  Australian Dollar          80203.850722
# 2017  Australian Dollar          80407.448452
# 2000               Euro          27950.103312
# 2001               Euro          28525.480599
# 2002               Euro          29266.445737
# 2003               Euro          29792.470499
# 2004               Euro          30888.209994
# 2005               Euro          31795.430063
# 2006               Euro          32930.827747
# 2007               Euro          33918.386510
# 2008               Euro          35239.176867
# 2009               Euro          35974.813515
# 2010               Euro          36436.831209
# 2011               Euro          37176.416607
# ...                 ...                   ...
# 2006          US Dollar          15788.041043
# 2007          US Dollar          17403.476599
# 2008          US Dollar          19086.880917
# 2009          US Dollar          17519.005620
# 2010          US Dollar          17530.170933
# 2011          US Dollar          18345.121936
# 2012          US Dollar          18854.027163
# 2013          US Dollar          19607.955536
# 2014          US Dollar          20392.893273
# 2015          US Dollar          21416.724468
# 2016          US Dollar          22562.385292
# 2017          US Dollar          24286.869243
# 2000          US Dollar           5576.006699
# 2001          US Dollar           5895.331499
# 2002          US Dollar           6153.414757
# 2003          US Dollar           6562.257351
# 2004          US Dollar           7102.612860
# 2005          US Dollar           7869.101211
# 2006          US Dollar           9223.898465
# 2007          US Dollar          10167.689623
# 2008          US Dollar          11151.190392
# 2009          US Dollar          10235.185518
# 2010          US Dollar          10241.708665
# 2011          US Dollar          10717.830135
# 2012          US Dollar          11015.149487
# 2013          US Dollar          11455.619508
# 2014          US Dollar          11914.206230
# 2015          US Dollar          12512.362452
# 2016          US Dollar          13181.695594
# 2017          US Dollar          14189.196450
#
# [2520 rows x 4 columns]

# %% [markdown]
# * We can also extract specific rows, say all having `In 2017 constant prices at 2017 USD exchange rates` as `Series` and `2017` as `Year`. Name the new object as `wage17`
#
# * Afterwards, let's order the Dataframe and name it `wage17_ordered`

# %%
# Extract specific rows
array17 = ['In 2017 constant prices at 2017 USD exchange rates'] 
wage17 = wagec.loc[(wagec['Year'] == 2017) & wagec['Series'].isin(array17)]
wage17_ordered = wage17.sort_values('Average Annual Wages', ascending=True)
wage17_ordered
# Out:
#               Country                                             Series  \
# 2087           Mexico  In 2017 constant prices at 2017 USD exchange r...
# 1709          Hungary  In 2017 constant prices at 2017 USD exchange r...
# 1853           Poland  In 2017 constant prices at 2017 USD exchange r...
# 2519        Lithuania  In 2017 constant prices at 2017 USD exchange r...
# 1889  Slovak Republic  In 2017 constant prices at 2017 USD exchange r...
# 1601   Czech Republic  In 2017 constant prices at 2017 USD exchange r...
# 2447           Latvia  In 2017 constant prices at 2017 USD exchange r...
# 2033          Estonia  In 2017 constant prices at 2017 USD exchange r...
# 2375            Chile  In 2017 constant prices at 2017 USD exchange r...
# %% [markdown]
# ## $\color{blue}{\text{Task: What is the shape of "wage17_ordered"?}}$

# %%
# Type your code here:
wage17_ordered.shape
# Out:
# (35, 5)

# %% [markdown]
# * After many modificactions, we might want to save our new DataFrame as a CSV file.

# %%
# Export a DataFrame to CSV
wage17_ordered.to_csv('wage17.csv')

# %% [markdown]
# # $\color{blue}{\text{Descriptive Statistics}}$
#
# * We can use the method `describe` to obtain a nummerical summary of the dataset

# %%
# Nummerical summary
wage17_ordered.describe()
# Out:
#          Year  Average Annual Wages
# count    35.0             35.000000
# mean   2017.0          40099.286033
# std       0.0          21743.599359
# min    2017.0           8592.534240
# 25%    2017.0          18927.520851
# 50%    2017.0          42409.789755
# 75%    2017.0          51369.057799
# max    2017.0          90661.520643

# %% [markdown]
# * We can get the summary for a specific column

# %%
# Nummerical summary of a specific column
wage17_ordered['Average Annual Wages'].describe()
# Out:
# count       35.000000
# mean     40099.286033
# std      21743.599359
# min       8592.534240
# 25%      18927.520851
# 50%      42409.789755
# 75%      51369.057799
# max      90661.520643
# Name: Average Annual Wages, dtype: float64

# %% [markdown]
# ## $\color{blue}{\text{Description.}}$
#
# * This is a summary of the Average Annual Wages of the 35 OECD countries in the year 2017, given in US Dollars (with constant prices at 2017 USD exchange rates). The mean annual wage is of about `US$40,100.00` with a standard deviation of `US$21,744.00`. The minimum is of about `US$8,593.00` and the maximum of `US$90,662.00`. From these countries; 25% have an average annual wage between `US$8,593.00`and `US$18,928.00`, 25% have an average annual wage between `US$51,370.00`and `US$90,662.00` and the middle half of the countries; that is, the middle 50% have an average annual wage between `US$18,928.00`and `US$51,370.00`.

# %% [markdown]
# * For a visual descriptin, we can plot a histogram for `Average Annual Wages`

# %%
# Histogram
wage17_ordered['Average Annual Wages'].hist(bins=8)

# %% [markdown]
# ## $\color{blue}{\text{Description.}}$
#
# * From the histogram we can see that about 9 countries have average annual wages less than `US$20,000.00` and about 2 countries above `US$80,000.00`. Also, 9 countries have average annual wages between `US$40,000.00` and `US$50,000.00`

# %% [markdown]
# * We can draw a horizontal boxplot for `Average Annual Wages`using seaborn

# %%
# Boxplot
sns.boxplot(x=wage17_ordered['Average Annual Wages'])

# %% [markdown]
# * Or a vertical one

# %%
# Boxplot
wage17_ordered.boxplot(column='Average Annual Wages', sym='o', return_type='axes')

# %% [markdown]
# ## $\color{blue}{\text{Description.}}$
#
# From this boxplots we can see that there are no outliers

# %% [markdown]
# * We can also add a new column to the DataFrame. Let's add the individual deviations

# %%
# Ad a new column
wage17_ordered['Individual stdev'] = ((wage17_ordered['Average Annual Wages'] - wage17_ordered['Average Annual Wages'].mean()).apply(abs) / wage17_ordered['Average Annual Wages'].std())
wage17_ordered.sort_values(by='Average Annual Wages', ascending=True)
# Out:
#               Country                                             Series  \
# 2087           Mexico  In 2017 constant prices at 2017 USD exchange r...
# 1709          Hungary  In 2017 constant prices at 2017 USD exchange r...
# 1853           Poland  In 2017 constant prices at 2017 USD exchange r...
# 2519        Lithuania  In 2017 constant prices at 2017 USD exchange r...
# 1673  US Dollar          44466.304646

# %%
wageGer.shape #we used this command to know the shape of the Data Frame
#this hows the number of columns and rows, for a better organization
# Out:
# (18, 5)

# %%
wageGer.describe() #here we tell the program to give us a nummerical summary of our dataset
# Out:
#               Year  Average Annual Wages
# count    18.000000             18.000000
# mean   2008.500000          40816.848233
# std       5.338539           1694.226294
# min    2000.000000          39128.538896
# 25%    2004.250000          39644.022324
# 50%    2008.500000          39896.129226
# 75%    2012.750000          41678.811580
# max    2017.000000          44466.304646

# %%
wageGer['Average Annual Wages'].describe()
# Out:
# count       18.000000
# mean     40816.848233
# std       1694.226294
# min      39128.538896
# 25%      39644.022324
# 50%      39896.129226
# 75%      41678.811580
# max      44466.304646
# Name: Average Annual Wages, dtype: float64

# %%
wageGer['Average Annual Wages'].hist(bins=8)

# %%
sns.boxplot(y=wageGer['Average Annual Wages'])

# %%
wageGer.boxplot(column='Average Annual Wages',sym ='o',return_type=('axes'))

# %%
# Export a DataFrame to CSV
wageGer.to_csv('wagemex.csv') #here we exported our data to a csv file

# %%
wageGer #just testing that everything was working fine
# Out:
#       Country                                             Series  Year  \
# 1656  Germany  In 2017 constant prices at 2017 USD exchange r...  2000
# 1657  Germany  In 2017 constant prices at 2017 USD exchange r...  2001
# 1658  Germany  In 2017 constant prices at 2017 USD exchange r...  2002
# 1659  Germany  In 2017 constant prices at 2017 USD exchange r...  2003
# 1660  Germany  In 2017 constant prices at 2017 USD exchange r...  2004
# 1661  Germany  In 2017 constant prices at 2017 USD exchange r...  2005
# 1662  Germany  In 2017 constant prices at 2017 USD exchange r...  2006
# 1663  Germany  In 2017 constant prices at 2017 USD exchange r...  2007
# 1664  Germany  In 2017 constant prices at 2017 USD exchange r...  2008
# 1665  Germany  In 2017 constant prices at 2017 USD exchange r...  2009
# 1666  Germany  In 2017 constant prices at 2017 USD exchange r...  2010
# 1667  Germany  In 2017 constant prices at 2017 USD exchange r...  2011
# 1668  Germany  In 2017 constant prices at 2017 USD exchange r...  2012
# 1669  Germany  In 2017 constant prices at 2017 USD exchange r...  2013
# 1670  Germany  In 2017 constant prices at 2017 USD exchange r...  2014
# 1671  Germany  In 2017 constant prices at 2017 USD exchange r...  2015
# 1672  Germany  In 2017 constant prices at 2017 USD exchange r...  2016
# 1673  Germany  In 2017 constant prices at 2017 USD exchange r...  2017
#
#            Unit  Average Annual Wages
# 1656  US Dollar          39128.538896
# 1657  US Dollar          39519.120333
# 1658  US Dollar          39726.046421
# 1659  US Dollar          39674.092556
# 1660  US Dollar          39671.775123
# 1661  US Dollar          39602.379146
# 1662  US Dollar          39634.771390
# 1663  US Dollar          39567.103929
# 1664  US Dollar          39817.416679
# 1665  US Dollar          39974.841774
# 1666  US Dollar          40153.724720
# 1667  US Dollar          40838.372958
# 1668  US Dollar          41305.053469
# 1669  US Dollar          41803.397618
# 1670  US Dollar          42444.010935
# 1671  US Dollar          43366.732799
# 1672  US Dollar          44009.584810
# 1673  US Dollar          44466.304646

# %% [markdown]
# ## $\color{blue}{\text{Task: Fit a linear model to the above German case:}}$
# First let's take a look at our data. For this we use matplotlib:

# %%
# We use the time as the independent variable and the wages as the dependent variable:
x = wageGer['Year']
y = wageGer['Average Annual Wages']

# Now we give the specifications of the graph: 

plt.figure(figsize=(7,7), dpi=110)
plt.plot(x, y, '*', color='red')
plt.xticks(ticks=np.arange(2000, 2020, 2), fontsize=12, rotation=30, ha='center', va='top')
plt.yticks(ticks=np.arange(39128.538896, 44466.304646, 1000), fontsize=12, rotation=0, ha='right', va='top')
#grid are the lines that form the squares in the graph
plt.grid(linestyle='--', linewidth=1, alpha=0.75) 
plt.tick_params(axis='both',bottom=True, top=False, left=True, right=False, direction='in', which='major', grid_color='black')
plt.title('Year vs Average Annual Wages for Germany', fontsize=12)
plt.show()

# %% [markdown]
# ## $\color{red}{\text{From the graph we can see a linear behaviour of our data, so let's fit a linear model. For this we use LinearRegression that we import from sklearn:}}$

# %%
from sklearn.linear_model import LinearRegression

x_a = pd.DataFrame({"A": wageGer['Year']}).to_numpy()
y_a = pd.DataFrame({"A": wageGer['Average Annual Wages']}).to_numpy()

model = LinearRegression().fit(x_a, y_a)
print("Model fitted successfully!")
# Out:
# Model fitted successfully!

# %% [markdown]
# Define by m and by b the slope and the y intercept of the linear model, respectively. This is done by calling .coef_ and .intercept

# %%
b = model.intercept_
m = model.coef_
print('The y intercept and the slope are:', b, m)
# Out:
# The y intercept and the slope are: [-529057.4643037] [[283.73129825]]

# %% [markdown]
# Define the linear model as yfit in the form: y=mx+b

# %%
yfit = m*x_a + b

# %% [markdown]
# Now let's plot the data together with the fitted linear model

# %%
plt.figure(figsize=(7,7), dpi=100)
plt.plot(x, y, '^', color='red')
plt.plot(x_a, yfit)
plt.xticks(ticks=np.arange(2000, 2020, 2), fontsize=12, rotation=30, ha='center', va='top')
plt.yticks(ticks=np.arange(39128.538896, 44466.304646, 1000), fontsize=12, rotation=0, ha='right', va='top')
plt.grid(linestyle='--', linewidth=0.5, alpha=0.15)
plt.tick_params(axis='both',bottom=True, top=False, left=True, right=False, direction='in', which='major', grid_color='orange')
plt.title('Year vs Average Annual Wages for Germany with fitted linear model', fontsize=12)
plt.show()

# %% [markdown]
# How good our model is? Does it work satisfactorily?
# To answer this question we use the coefficient of determination 𝑅2R2: a statistical measure of how well the model approximates the real data points. An 𝑅2R2 of 1 indicates that the regression predictions perfectly fit the data.
# We obtain 𝑅2R2 with .score() called on model

# %%
# Define R^2 as r_sq
r_sq = model.score(x_a, y_a)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.7993123352881822

# %% [markdown]
# From the above graph and the coefficient of determination we can conclude that a linear model works satisfactorily to predict the future behaviour of Mexico's average annual wages. Of course, there are some limitations.
# Let's see the y-values of the fitted model:

# %%
y_val = model.predict(x_a)
print('Model values:', y_val, sep='\n')
# Out:
# Model values:
# [[38405.13219828]
#  [38688.86349653]
#  [38972.59479478]
#  [39256.32609303]
#  [39540.05739128]
#  [39823.78868953]
#  [40107.51998778]
#  [40391.25128603]
#  [40674.98258429]
#  [40958.71388254]
#  [41242.44518079]
#  [41526.17647904]
#  [41809.90777729]
#  [42093.63907554]
#  [42377.37037379]
#  [42661.10167204]
#  [42944.83297029]
#  [43228.56426854]]

# %% [markdown]
# Now let's predict the average annual wages of the next 18 years; that is, from 2019 to 2036:

# %%
# Here we sum 19 to x_a:
y_pred = model.predict(x_a+19)
print('Model predictions for the next 18 years:', y_pred, sep='\n')
# Out:
# Model predictions for the next 18 years:
# [[43796.02686505]
#  [44079.7581633 ]
#  [44363.48946155]
#  [44647.2207598 ]
#  [44930.95205805]
#  [45214.6833563 ]
#  [45498.41465455]
#  [45782.1459528 ]
#  [46065.87725105]
#  [46349.60854931]
#  [46633.33984756]
#  [46917.07114581]
#  [47200.80244406]
#  [47484.53374231]
#  [47768.26504056]
#  [48051.99633881]
#  [48335.72763706]
#  [48619.45893531]]

# %% [markdown]
# If we want to predict the average annual wage in a specific year we can define our linear model as a function and then evaluate in the desired year:

# %%
#Define the model as `lin_model`
def lin_mod(x1):
    return m*x1+b

print('The average annual wage in the year 2036 is:', lin_mod(2036))
# Out:
# The average annual wage in the year 2036 is: [[48619.45893531]]

# %%
# Fitting Polynomial Regression to the dataset 
from sklearn.preprocessing import PolynomialFeatures 

x_ger = pd.DataFrame({"A": wageGer['Year']}).to_numpy()
y_ger = pd.DataFrame({"A": wageGer['Average Annual Wages']}).to_numpy()

# Below we secify the degree of the polynomial:

poly = PolynomialFeatures(degree = 4) 
X_poly = poly.fit_transform(x_ger) 
  
poly.fit(X_poly, y_ger) 
lin2 = LinearRegression() 
model_ger = lin2.fit(X_poly, y_ger)

# %%
#Scatter plot
plt.figure(figsize=(7,7), dpi=100)

plt.scatter(x, y, color = 'yellow') 
plt.plot(x_ger, lin2.predict(X_poly), color="red")

plt.xticks(ticks=np.arange(2000, 2020, 2), fontsize=12, rotation=30, ha='center', va='top')
plt.yticks(ticks=np.arange(39128.538896, 44466.304646, 1000), fontsize=12, rotation=0, ha='right', va='top')
plt.grid(linestyle='--', linewidth=0.5, alpha=0.15)
plt.tick_params(axis='both',bottom=True, top=False, left=True, right=False, direction='in', which='major', grid_color='black')
plt.title('Year vs Average Annual Wages for Germany with fitted polynomial model', fontsize=12)

plt.show()

# %%
# Define R^2 as r_ger for Germany
r_ger = model_ger.score(X_poly, y_ger)
print("The coefficient of determination is {}".format(r_ger))
# Out:
# The coefficient of determination is 0.986414835375411

# %%
coefger = model_ger.coef_
print("The coefficients of the model are {}".format(coefger))
# Out:
# The coefficients of the model are [[ 0.00000000e+00  2.51487078e+00  4.08467714e+03 -2.72117779e+00
#    5.09857592e-04]]

# %%
lin2.predict(X_poly)
# Out:
# array([[39442.86153126],
#        [39458.99411297],
#        [39471.66518402],
#        [39489.03919888],
#        [39519.29284286],
#        [39570.61504555],
#        [39651.20696926],
#        [39769.28200912],
#        [39933.06580639],
#        [40150.79622841],
#        [40430.72338486],
#        [40781.10962391],
#        [41210.22952175],
#        [41726.36989784],
#        [42337.82981014],
#        [43052.9205513 ],
#        [43879.9656477 ],
#        [44827.30086231]])

# %% [markdown]
# ![alt text](NN.jpg "Average Annual Wages")
